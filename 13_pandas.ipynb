# %%
import pandas as pd
import seaborn as sns

sns.load_dataset("titanic")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0    1.0    0.0   7.2500        S   Third
# 1           1       1  female  38.0    1.0    0.0  71.2833        C   First
# 2           1       3  female  26.0    0.0    0.0   7.9250        S   Third
# 3           1       1  female  35.0    1.0    0.0  53.1000        S   First
# 4           0       3    male  35.0    0.0    0.0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 516         1       2  female  34.0    0.0    0.0  10.5000        S  Second
# 517         0       3    male   NaN    0.0    0.0  24.1500        Q   Third
# 518         1       2  female  36.0    1.0    0.0  26.0000        S  Second
# 519         0       3    male  32.0    0.0    0.0   7.8958        S   Third
# 520         1       1  female   NaN    NaN    NaN      NaN      NaN     NaN
#
#        who adult_male deck  embark_town alive  alone
# ...
